# %%
from ublox_gps import UbloxGps
import serial
# Can also use SPI here - import spidev
# I2C is not supported

port = serial.Serial('/dev/ttyACM0', baudrate=38400, timeout=1)
gps = UbloxGps(port)

def run():
  
  try: 
    print("Listenting for UBX Messages.")
    while True:
      try: 
        coords = gps.geo_coords()
        print(coords.lon, coords.lat)
      except (ValueError, IOError) as err:
        print(err)
  
  finally:
    port.close()

if __name__ == '__main__':
  run()
# Out:
# Listenting for UBX Messages.
# -119.8031714 39.4264247
# -119.8031706 39.4264246
# -119.80316979999999 39.4264247
# -119.80316909999999 39.426424999999995
# -119.80316839999999 39.4264252
# -119.8031675 39.4264255
# -119.80316699999999 39.4264258
# -119.8031666 39.426426299999996
# -119.8031659 39.4264271
# -119.8031652 39.4264277
# -119.80316429999999 39.4264284
# -119.803164 39.4264291
# -119.8031637 39.4264297
# -119.8031633 39.4264303
# -119.8031627 39.4264309
# -119.8031621 39.4264315
# -119.8031618 39.426432
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-321a456fe9e0> in <module>
#      22
#      23 if __name__ == '__main__':
# ---> 24   run()
#
# <ipython-input-8-321a456fe9e0> in run()
#      13     while True:
#      14       try:
# ---> 15         coords = gps.geo_coords()
#      16         print(coords.lon, coords.lat)
#      17       except (ValueError, IOError) as err:
#
# /usr/local/lib/python3.6/dist-packages/ublox_gps/ublox_gps.py in geo_coords(self)
#     205         self.send_message(sp.NAV_CLS, self.nav_ms.get('PVT'))
#     206         parse_tool = core.Parser([sp.NAV_CLS])
# --> 207         cls_name, msg_name, payload = parse_tool.receive_from(self.hard_port)
#     208         s_payload = self.scale_NAV_PVT(payload)
#     209         return s_payload
#
# /usr/local/lib/python3.6/dist-packages/ublox_gps/core.py in receive_from(self, stream)
#     389         while True:
#     390             # Search for the prefix
# --> 391             buff = self._read_until(stream, terminator=self.PREFIX)
#     392             if buff[-2:] == self.PREFIX:
#     393                 break
#
# /usr/local/lib/python3.6/dist-packages/ublox_gps/core.py in _read_until(stream, terminator, size)
#     437         line = bytearray()
#     438         while True:
# --> 439             c = stream.read(1)
#     440             if c:
#     441                 line += c
#
# ~/.local/lib/python3.6/site-packages/serial/serialposix.py in read(self, size)
#     563         while len(read) < size:
#     564             try:
# --> 565                 ready, _, _ = select.select([self.fd, self.pipe_abort_read_r], [], [], timeout.time_left())
#     566                 if self.pipe_abort_read_r in ready:
#     567                     os.read(self.pipe_abort_read_r, 1000)
#
# KeyboardInterrupt:

# %%
import serial
from ublox_gps import UbloxGps

port = serial.Serial('/dev/ttyACM0', baudrate=38400, timeout=1)
gps = UbloxGps(port)

def run():

    try:
        print("Listening for UBX Messages")
        while True:
            try:
                veh = gps.veh_attitude()
                print("Roll: ", veh.roll)
                print("Pitch: ", veh.pitch)
                print("Heading: ", veh.heading)
                print("Roll Acceleration: ", veh.accRoll)
                print("Pitch Acceleration: ", veh.accPitch)
                print("Heading Acceleration: ", veh.accHeading)
            except (ValueError, IOError) as err:
                print(err)

    finally:
        port.close()


if __name__ == '__main__':
    run()
# Out:
# Listening for UBX Messages
# Roll:  0.0
# Pitch:  0.0
# Heading:  0.0
# Roll Acceleration:  2000000
# Pitch Acceleration:  20.04548
# Heading Acceleration:  171.1082
# Roll:  0.0
# Pitch:  0.0
# Heading:  0.0
# Roll Acceleration:  2000000
# Pitch Acceleration:  20.04548
# Heading Acceleration:  171.1082
# Roll:  0.0
# Pitch:  0.0
# Heading:  0.0
# Roll Acceleration:  2000000
# Pitch Acceleration:  20.04548
# Heading Acceleration:  171.1082
# Roll:  0.0
# Pitch:  0.0
# Heading:  0.0
# Roll Acceleration:  2000000
# Pitch Acceleration:  20.04548
# Heading Acceleration:  171.1082
# Roll:  0.0
# Pitch:  0.0
# Heading:  0.0
# Roll Acceleration:  2000000
# Pitch Acceleration:  20.04548
# Heading Acceleration:  171.1082
# Roll:  0.0
# Pitch:  0.0
# Heading:  0.0
# Roll Acceleration:  2000000
# Pitch Acceleration:  20.04548
# Heading Acceleration:  171.1082
# Roll:  0.0
# Pitch:  0.0
# Heading:  0.0
# Roll Acceleration:  2000000
# Pitch Acceleration:  20.04548
# Heading Acceleration:  171.1082
# Roll:  0.0
# Pitch:  0.0
# Heading:  0.0
# Roll Acceleration:  2000000
# Pitch Acceleration:  20.04548
# Heading Acceleration:  171.1082
# Roll:  0.0
# Pitch:  0.0
# Heading:  0.0
# Roll Acceleration:  2000000
# Pitch Acceleration:  20.04548
# Heading Acceleration:  171.1082
# Roll:  0.0
# Pitch:  0.0
# Heading:  0.0
# Roll Acceleration:  2000000
# Pitch Acceleration:  20.04548
# Heading Acceleration:  171.1082
# Roll:  0.0
# Pitch:  0.0
# Heading:  0.0
# Roll Acceleration:  2000000
# Pitch Acceleration:  20.04548
# Heading Acceleration:  171.1082
# Roll:  0.0
# Pitch:  0.0
# Heading:  0.0
# Roll Acceleration:  2000000
# Pitch Acceleration:  20.04548
# Heading Acceleration:  171.1082
# Roll:  0.0
# Pitch:  0.0
# Heading:  0.0
# Roll Acceleration:  2000000
# Pitch Acceleration:  20.04548
# Heading Acceleration:  171.1082
# Roll:  0.0
# Pitch:  0.0
# Heading:  0.0
# Roll Acceleration:  2000000
# Pitch Acceleration:  20.04548
# Heading Acceleration:  171.1082
# Roll:  0.0
# Pitch:  0.0
# Heading:  0.0
# Roll Acceleration:  2000000
# Pitch Acceleration:  20.04548
# Heading Acceleration:  171.1082
# Roll:  0.0
# Pitch:  0.0
# Heading:  0.0
# Roll Acceleration:  2000000
# Pitch Acceleration:  20.04548
# Heading Acceleration:  171.1082
# Roll:  0.0
# Pitch:  0.0
# Heading:  0.0
# Roll Acceleration:  2000000
# Pitch Acceleration:  20.04548
# Heading Acceleration:  171.1082
# Roll:  0.0
# Pitch:  0.0
# Heading:  0.0
# Roll Acceleration:  2000000
# Pitch Acceleration:  20.04548
# Heading Acceleration:  171.1082
# Roll:  0.0
# Pitch:  0.0
# Heading:  0.0
# Roll Acceleration:  2000000
# Pitch Acceleration:  20.04597
# Heading Acceleration:  171.11612000000002
# Roll:  0.0
# Pitch:  0.0
# Heading:  0.0
# Roll Acceleration:  2000000
# Pitch Acceleration:  20.046460000000003
# Heading Acceleration:  171.12396
# Roll:  0.0
# Pitch:  0.0
# Heading:  0.0
# Roll Acceleration:  2000000
# Pitch Acceleration:  20.04697
# Heading Acceleration:  171.13212000000001
# Roll:  0.0
# Pitch:  0.0
# Heading:  0.0
# Roll Acceleration:  2000000
# Pitch Acceleration:  20.047310000000003
# Heading Acceleration:  171.13768000000002
# Roll:  0.0
# Pitch:  0.0
# Heading:  0.0
# Roll Acceleration:  2000000
# Pitch Acceleration:  20.04774
# Heading Acceleration:  171.14444
# Roll:  0.0
# Pitch:  0.0
# Heading:  0.0
# Roll Acceleration:  2000000
# Pitch Acceleration:  20.04823
# Heading Acceleration:  171.15232
# Roll:  0.0
# Pitch:  0.0
# Heading:  0.0
# Roll Acceleration:  2000000
# Pitch Acceleration:  20.04869
# Heading Acceleration:  171.15978
# Roll:  0.0
# Pitch:  0.0
# Heading:  0.0
# Roll Acceleration:  2000000
# Pitch Acceleration:  20.04917
# Heading Acceleration:  171.16742000000002
# Roll:  0.0
# Pitch:  0.0
# Heading:  0.0
# Roll Acceleration:  2000000
# Pitch Acceleration:  20.04963
# Heading Acceleration:  171.17494000000002
# Roll:  0.0
# Pitch:  0.0
# Heading:  0.0
# Roll Acceleration:  2000000
# Pitch Acceleration:  20.04963
# Heading Acceleration:  171.17494000000002
# Roll:  0.0
# Pitch:  0.0
# Heading:  0.0
# Roll Acceleration:  2000000
# Pitch Acceleration:  20.04963
# Heading Acceleration:  171.17494000000002
# Roll:  0.0
# Pitch:  0.0
# Heading:  0.0
# Roll Acceleration:  2000000
# Pitch Acceleration:  20.04963
# Heading Acceleration:  171.17494000000002
# Roll:  0.0
# Pitch:  0.0
# Heading:  0.0
# Roll Acceleration:  2000000
# Pitch Acceleration:  20.04963
# Heading Acceleration:  171.17494000000002
# Roll:  0.0
# Pitch:  0.0
# Heading:  0.0
# Roll Acceleration:  2000000
# Pitch Acceleration:  20.04963
# Heading Acceleration:  171.17494000000002
# Roll:  0.0
# Pitch:  0.0
# Heading:  0.0
# Roll Acceleration:  2000000
# Pitch Acceleration:  20.04963
# Heading Acceleration:  171.17494000000002
# Roll:  0.0
# Pitch:  0.0
# Heading:  0.0
# Roll Acceleration:  2000000
# Pitch Acceleration:  20.04963
# Heading Acceleration:  171.17494000000002
# Roll:  0.0
# Pitch:  0.0
# Heading:  0.0
# Roll Acceleration:  2000000
# Pitch Acceleration:  20.04963
# Heading Acceleration:  171.17494000000002
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-a6a5e86df3fb> in <module>
#      27
#      28 if __name__ == '__main__':
# ---> 29     run()
#
# <ipython-input-9-a6a5e86df3fb> in run()
#      12         while True:
#      13             try:
# ---> 14                 veh = gps.veh_attitude()
#      15                 print("Roll: ", veh.roll)
#      16                 print("Pitch: ", veh.pitch)
#
# /usr/local/lib/python3.6/dist-packages/ublox_gps/ublox_gps.py in veh_attitude(self)
#     265         self.send_message(sp.NAV_CLS, self.nav_ms.get('ATT'))
#     266         parse_tool = core.Parser([sp.NAV_CLS])
# --> 267         cls_name, msg_name, payload = parse_tool.receive_from(self.hard_port)
#     268         s_payload = self.scale_NAV_ATT(payload)
#     269         return s_payload
#
# /usr/local/lib/python3.6/dist-packages/ublox_gps/core.py in receive_from(self, stream)
#     389         while True:
#     390             # Search for the prefix
# --> 391             buff = self._read_until(stream, terminator=self.PREFIX)
#     392             if buff[-2:] == self.PREFIX:
#     393                 break
#
# /usr/local/lib/python3.6/dist-packages/ublox_gps/core.py in _read_until(stream, terminator, size)
#     437         line = bytearray()
#     438         while True:
# --> 439             c = stream.read(1)
#     440             if c:
#     441                 line += c
#
# ~/.local/lib/python3.6/site-packages/serial/serialposix.py in read(self, size)
#     563         while len(read) < size:
#     564             try:
# --> 565                 ready, _, _ = select.select([self.fd, self.pipe_abort_read_r], [], [], timeout.time_left())
#     566                 if self.pipe_abort_read_r in ready:
#     567                     os.read(self.pipe_abort_read_r, 1000)
#
# KeyboardInterrupt:

# %%
import sys
import glob

def get_serial_ports():
    """ Lists serial port names

        :raises EnvironmentError:
            On unsupported or unknown platforms
        :returns:
            A list of the serial ports available on the system
    """
    if sys.platform.startswith('win'):
        ports = ['COM%s' % (i + 1) for i in range(256)]
    elif sys.platform.startswith('linux') or sys.platform.startswith('cygwin'):
        # this excludes your current terminal "/dev/tty"
        ports = glob.glob('/dev/tty[A-Za-z]*')
    elif sys.platform.startswith('darwin'):
        ports = glob.glob('/dev/tty.*')
    else:
        raise EnvironmentError('Unsupported platform')

    result = []
    for port in ports:
        try:
            s = serial.Serial(port)
            s.close()
            result.append(port)
        except (OSError, serial.SerialException):
            pass
    return result

get_serial_ports()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-132217f2f926> in get_serial_ports()
#      24         try:
# ---> 25             s = serial.Serial(port)
#      26             s.close()
#
# NameError: name 'serial' is not defined
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-132217f2f926> in <module>
#      30     return result
#      31
# ---> 32 get_serial_ports()
#
# <ipython-input-1-132217f2f926> in get_serial_ports()
#      26             s.close()
#      27             result.append(port)
# ---> 28         except (OSError, serial.SerialException):
#      29             pass
#      30     return result
#
# NameError: name 'serial' is not defined
